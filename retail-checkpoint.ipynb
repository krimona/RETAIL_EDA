# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
retail=pd.read_csv(r'C:\Users\monak\Downloads\SampleSuperstore.csv')
retail.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
retail.shape
# Out:
# (9994, 13)

# %%
retail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
retail.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
retail.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
plt.figure(figsize=(7,7))
sns.boxplot(retail['Sales'])
plt.show()

# %%
plt.figure(figsize=(7,7))
sns.boxplot(retail['Quantity'])
plt.show()

# %%
plt.figure(figsize=(7,7))
sns.boxplot(retail['Discount'])
plt.show()

# %%
plt.figure(figsize=(7,7))
sns.boxplot(retail['Profit'])
plt.show()

# %%
sns.countplot(retail['Segment'])
plt.show()

# %%
sns.countplot(retail['Category'])
plt.show()

# %% [markdown]
# **COUSTOMER HAS ORDERED MORE OFFICE SUPPLIES**

# %%
plt.figure(figsize=(15,10))
sns.countplot(retail['Sub-Category'])
plt.show()

# %% [markdown]
# **BINDERS AND PAPER ARE ORDERED MOST AND MACHINES AND COPIERS ARE ORDERED LESS.**

# %%
sns.barplot(x='Segment',y='Sales',data=retail)
plt.show()

# %% [markdown]
# **SALES OF HOME OFFICE PRODUCTS WAS MORE**

# %%
sns.barplot(x='Segment',y='Profit',data=retail)
plt.show()

# %% [markdown]
# **HOME OFFICE PRODUCTS HAS GAIN MORE PROFITS**

# %%
sns.barplot(x='Segment',y='Discount',data=retail)
plt.show()

# %%
sns.barplot(x='Segment',y='Quantity',data=retail)
plt.show()

# %%
sns.barplot(x='Region',y='Sales',data=retail)
plt.show()

# %% [markdown]
# **SALES WAS MORE IN THE REGION OF SOUTH AND EAST**

# %%
sns.barplot(x='Region',y='Profit',data=retail)
plt.show()

# %% [markdown]
# **PROFIT WAS MORE IN THE WEST REGION AND LESS IN CENTRAL REGION**

# %%
sns.barplot(x='Region',y='Discount',data=retail)
plt.show()

# %%
sns.barplot(x='Category',y='Sales',data=retail)
plt.show()

# %% [markdown]
# **SALE WAS MORE IN TECH CATEGORY**

# %%
sns.barplot(x='Category',y='Profit',data=retail)
plt.show()

# %% [markdown]
# **PROFIT WAS MORE IN TECH CATEGORY**

# %%
sns.barplot(x='Category',y='Discount',data=retail)
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.barplot(x='Sub-Category',y='Sales',data=retail)
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.barplot(x='Sub-Category',y='Profit',data=retail)
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.barplot(x='Sub-Category',y='Discount',data=retail)
plt.show()

# %%
sns.countplot(x='Segment',hue='Category',data=retail)
plt.show()

# %%
sns.countplot(x='Region',hue='Category',data=retail)
plt.show()

# %%
plt.figure(figsize=(55,20))
sns.barplot(x='State',y='Sales',data=retail)
plt.show()

# %% [markdown]
# **sales was great in Wyoming and Vermont states and less in South Dakota and Kansas**

# %%
plt.figure(figsize=(55,20))
sns.barplot(x='State',y='Profit',data=retail)
plt.show()

# %% [markdown]
# **Vermont states given more profits to sales**

# %% [markdown]
# # OBSERVATION

# %% [markdown]
# **OFFICE SUPLIES GOT MORE ORDERS AND PROFIT**
#
#
#
#
# **SALES AND PROFIT ARE LOW IN CENTRAL REGION**
#
#
#
# **PROFITS ARE LESS IN FURNITURE CATEGORY**
#
#
#
# **CATEGORIES WHICH GOT MORE DISCOUNT HAVE GIVEN LESS PROFITS**
